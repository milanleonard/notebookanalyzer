# %% [markdown]
# # Title of the notebook
# ## Subtitle
# ----
# there is a line to remove from the text

# %%
import numpy
import matplotlib.pyplot as plt # comments shouldnt matter, this should just read as matplotlib

# %%
# another code cell
import scipy

# %% [markdown]
# another markdown cell with text.
